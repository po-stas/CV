# %% [markdown]
# ### Object Detection
# Для этого ДЗ был выбран готовый датасет с RoboFlow,
#
#
# https://public.roboflow.com/object-detection/mask-wearing

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = Image.open('dataset/train/sars-gettyimages-157005245_jpg.rf.e6d5283c235edb22b1eb63fc0f8e47e9.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x675 at 0x7F6A48626FA0>

# %%
# Вобщем люди в масках - один класс и люди без масок - второй. Баунды на лица

# %%
# Всё загруженно и разложено, можно пробовать исполнять апи-шные скрипты

# %%
# !python keras-retinanet/keras_retinanet/bin/train.py --random-transform \
    --weights 'model/resnet50_coco_best_v2.1.0.h5' \
    --steps 100 \
    --epochs 20 \
    csv 'dataset/train/_annotations.csv' 'dataset/classes.csv'
# Out:
# 2021-06-28 23:07:44.104112: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "keras-retinanet/keras_retinanet/bin/train.py", line 530, in <module>
#     main()
#   File "keras-retinanet/keras_retinanet/bin/train.py", line 465, in main
#     train_generator, validation_generator = create_generators(args, backbone.preprocess_image)
#   File "keras-retinanet/keras_retinanet/bin/train.py", line 284, in create_generators
#     train_generator = CSVGenerator(
#   File "keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/csv_generator.py", line 158, in __init__
#     raise_from(ValueError('invalid CSV annotations file: {}: {}'.format(csv_data_file, e)), None)
#   File "<string>", line 3, in raise_from
# ValueError: invalid CSV annotations file: dataset/train/_annotations.csv: line 132: x2 (862) must be higher than x1 (862)

# %%
# Так, там координаты баундов кривые. Удалил эту запись вообще из файла

# %%
# !python keras-retinanet/keras_retinanet/bin/train.py --random-transform \
    --weights 'model/resnet50_coco_best_v2.1.0.h5' \
    --steps 100 \
    --epochs 20 \
    csv 'dataset/train/_annotations.csv' 'dataset/classes.csv'
# Out:
# 2021-06-28 23:14:38.062754: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-06-28 23:14:39.638824: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-28 23:14:39.640133: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-28 23:14:39.680646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 23:14:39.681051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 3080 Laptop GPU computeCapability: 8.6
# coreClock: 1.545GHz coreCount: 48 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 417.29GiB/s
# ...

# %%
# Таак.... идти туда и править чужой код?

# %%
# !python keras-retinanet/keras_retinanet/bin/train.py --random-transform \
    --weights 'model/resnet50_coco_best_v2.1.0.h5' \
    --steps 100 \
    --epochs 20 \
    csv 'dataset/train/_annotations.csv' 'dataset/classes.csv'
# Out:
# 2021-06-28 23:28:59.661571: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-06-28 23:29:01.204814: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-28 23:29:01.205519: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-28 23:29:01.242537: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 23:29:01.243814: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 3080 Laptop GPU computeCapability: 8.6
# coreClock: 1.545GHz coreCount: 48 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 417.29GiB/s
# ...

# %%
# Ну вобщем видимо это глупая затея, возможно эта штука работает на какой-нибудь древней версии TF

# %%
# !python keras-retinanet/keras_retinanet/bin/train.py --random-transform \
    --weights 'model/resnet50_coco_best_v2.1.0.h5' \
    --steps 100 \
    --epochs 20 \
    csv 'dataset/train/_annotations.csv' 'dataset/classes.csv'
# Out:
# 2021-06-28 23:51:54.914860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-06-28 23:51:56.442812: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-06-28 23:51:56.443509: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-06-28 23:51:56.489717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-28 23:51:56.490261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 3080 Laptop GPU computeCapability: 8.6
# coreClock: 1.545GHz coreCount: 48 deviceMemorySize: 15.75GiB deviceMemoryBandwidth: 417.29GiB/s
# ...

# %%
# Вобщем клонируем репозиторий, и не откатываемся на 89 коммитов назад. (как предлагают в лекции) 
# Ставим последнее состояние. И тогда все работает ок.
# Какое у него по-дефолту жуткое количество аутпута.
